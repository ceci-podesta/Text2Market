# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read s300news_summary

# %%
folder = 'data\hs300news_summary'
dfs = []

for file in os.listdir(folder):
    if file.endswith('.jsonl'):
        path = os.path.join(folder, file)
        df = pd.read_json(path, lines=True)
        dfs.append(df)

# Combinar todo en un solo DataFrame
df_news = pd.concat(dfs, ignore_index=True)

# %%
print(df_news.shape)
print(df_news.info())
df_news.head()
# Out:
# (1420362, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1420362 entries, 0 to 1420361
# Data columns (total 3 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   datetime  1420362 non-null  datetime64[ns]
#  1   title     987610 non-null   object
#  2   summary   1420362 non-null  object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 32.5+ MB
# None
#              datetime  title  \
# 0 2020-03-31 09:21:25   None
# 1 2020-03-31 09:21:25   None
# 2 2020-03-31 09:21:25   None
# 3 2020-04-01 10:55:31  银行股拉升
# 4 2020-04-01 10:55:31  银行股拉升
#
#                                              summary
# 0  中金：受疫情影响行业景气度下行，预计今年上市银行净利润增速同比下滑至3.7%，但近期估值调整...
# 1  中金：受疫情影响行业景气度下行，预计今年上市银行净利润增速同比下滑至3.7%，但近期估值调整...
# 2  中金：受疫情影响行业景气度下行，预计今年上市银行净利润增速同比下滑至3.7%，但近期估值调整...
# 3             【银行股拉升】银行股拉升，张家港行、青农商行涨3%，紫金银行、平安银行跟涨。
# 4             【银行股拉升】银行股拉升，张家港行、青农商行涨3%，紫金银行、平安银行跟涨。

# %%
df_news.title.value_counts().to_csv('outputs/news_title_counts.csv', header=['count'])

# %% [markdown]
# # Read sp500

# %%
folder = 'data\sp500_news'
dfs = []

for file in os.listdir(folder):
    if file.endswith('.jsonl'):
        path = os.path.join(folder, file)
        df = pd.read_json(path, lines=True)
        dfs.append(df)

# Combinar todo en un solo DataFrame
df_sp500 = pd.concat(dfs, ignore_index=True)

# %%
print(df_sp500.shape)
df_sp500.head()
# Out:
# (3049555, 101)
#         Date                                                Url  \
# 0 2025-04-15  https://www.nasdaq.com/articles/congress-trade...
# 1 2025-04-11  https://www.nasdaq.com/articles/looking-stocks...
# 2 2025-04-02  https://www.nasdaq.com/articles/insider-sale-d...
# 3 2025-03-28  https://www.nasdaq.com/articles/ex-dividend-re...
# 4 2025-03-28  https://www.nasdaq.com/articles/agilent-techno...
#
#                                              Article Stock_symbol  \
# 0  Representative Julie Johnson just filed new st...            a
# 1  Two factors often determine stock prices in th...            a
# 2  Daniel K Podolsky, a director at $A, sold 1,81...            a
# 3  Looking at the universe of stocks we cover at ...            a
# 4  The DividendRank formula at Dividend Channel r...            a
#
#   Article_title  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                       NaN         NaN         NaN         NaN         NaN
# 1                       NaN         NaN         NaN         NaN         NaN
# 2                       NaN         NaN         NaN         NaN         NaN
# 3                       NaN         NaN         NaN         NaN         NaN
# 4                       NaN         NaN         NaN         NaN         NaN
#
#    ...  Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  Unnamed: 95  \
# 0  ...          NaN          NaN          NaN          NaN          NaN
# 1  ...          NaN          NaN          NaN          NaN          NaN
# 2  ...          NaN          NaN          NaN          NaN          NaN
# 3  ...          NaN          NaN          NaN          NaN          NaN
# 4  ...          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 96 Unnamed: 97 Unnamed: 98 Unnamed: 99 Unnamed: 100
# 0         NaN         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN         NaN          NaN
#
# [5 rows x 101 columns]

# %%
unnamed_cols = [c for c in df.columns if c.startswith('Unnamed')]
print(f"Cantidad de columnas Unnamed: {len(unnamed_cols)}")
print(unnamed_cols[:10])  # ver las primeras 10
# Out:
# Cantidad de columnas Unnamed: 96
# ['Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14']

# %%
for c in unnamed_cols:
    n_nonnull = df[c].notna().sum()
    print(f"{c}: {n_nonnull} valores no nulos")
# Out:
# Unnamed: 5: 0 valores no nulos
# Unnamed: 6: 0 valores no nulos
# Unnamed: 7: 0 valores no nulos
# Unnamed: 8: 0 valores no nulos
# Unnamed: 9: 0 valores no nulos
# Unnamed: 10: 0 valores no nulos
# Unnamed: 11: 0 valores no nulos
# Unnamed: 12: 0 valores no nulos
# Unnamed: 13: 0 valores no nulos
# Unnamed: 14: 0 valores no nulos
# Unnamed: 15: 0 valores no nulos
# Unnamed: 16: 0 valores no nulos
# Unnamed: 17: 0 valores no nulos
# Unnamed: 18: 0 valores no nulos
# Unnamed: 19: 0 valores no nulos
# Unnamed: 20: 0 valores no nulos
# Unnamed: 21: 0 valores no nulos
# Unnamed: 22: 0 valores no nulos
# Unnamed: 23: 0 valores no nulos
# Unnamed: 24: 0 valores no nulos
# Unnamed: 25: 0 valores no nulos
# Unnamed: 26: 0 valores no nulos
# Unnamed: 27: 0 valores no nulos
# Unnamed: 28: 0 valores no nulos
# Unnamed: 29: 0 valores no nulos
# Unnamed: 30: 0 valores no nulos
# Unnamed: 31: 0 valores no nulos
# Unnamed: 32: 0 valores no nulos
# Unnamed: 33: 0 valores no nulos
# Unnamed: 34: 0 valores no nulos
# Unnamed: 35: 0 valores no nulos
# Unnamed: 36: 0 valores no nulos
# Unnamed: 37: 0 valores no nulos
# Unnamed: 38: 0 valores no nulos
# Unnamed: 39: 0 valores no nulos
# Unnamed: 40: 0 valores no nulos
# Unnamed: 41: 0 valores no nulos
# Unnamed: 42: 0 valores no nulos
# Unnamed: 43: 0 valores no nulos
# Unnamed: 44: 0 valores no nulos
# Unnamed: 45: 0 valores no nulos
# Unnamed: 46: 0 valores no nulos
# Unnamed: 47: 0 valores no nulos
# Unnamed: 48: 0 valores no nulos
# Unnamed: 49: 0 valores no nulos
# Unnamed: 50: 0 valores no nulos
# Unnamed: 51: 0 valores no nulos
# Unnamed: 52: 0 valores no nulos
# Unnamed: 53: 0 valores no nulos
# Unnamed: 54: 0 valores no nulos
# Unnamed: 55: 0 valores no nulos
# Unnamed: 56: 0 valores no nulos
# Unnamed: 57: 0 valores no nulos
# Unnamed: 58: 0 valores no nulos
# Unnamed: 59: 0 valores no nulos
# Unnamed: 60: 0 valores no nulos
# Unnamed: 61: 0 valores no nulos
# Unnamed: 62: 0 valores no nulos
# Unnamed: 63: 0 valores no nulos
# Unnamed: 64: 0 valores no nulos
# Unnamed: 65: 0 valores no nulos
# Unnamed: 66: 0 valores no nulos
# Unnamed: 67: 0 valores no nulos
# Unnamed: 68: 0 valores no nulos
# Unnamed: 69: 0 valores no nulos
# Unnamed: 70: 0 valores no nulos
# Unnamed: 71: 0 valores no nulos
# Unnamed: 72: 0 valores no nulos
# Unnamed: 73: 0 valores no nulos
# Unnamed: 74: 0 valores no nulos
# Unnamed: 75: 0 valores no nulos
# Unnamed: 76: 0 valores no nulos
# Unnamed: 77: 0 valores no nulos
# Unnamed: 78: 0 valores no nulos
# Unnamed: 79: 0 valores no nulos
# Unnamed: 80: 0 valores no nulos
# Unnamed: 81: 0 valores no nulos
# Unnamed: 82: 0 valores no nulos
# Unnamed: 83: 0 valores no nulos
# Unnamed: 84: 0 valores no nulos
# Unnamed: 85: 0 valores no nulos
# Unnamed: 86: 0 valores no nulos
# Unnamed: 87: 0 valores no nulos
# Unnamed: 88: 0 valores no nulos
# Unnamed: 89: 0 valores no nulos
# Unnamed: 90: 0 valores no nulos
# Unnamed: 91: 0 valores no nulos
# Unnamed: 92: 0 valores no nulos
# Unnamed: 93: 0 valores no nulos
# Unnamed: 94: 0 valores no nulos
# Unnamed: 95: 0 valores no nulos
# Unnamed: 96: 0 valores no nulos
# Unnamed: 97: 0 valores no nulos
# Unnamed: 98: 0 valores no nulos
# Unnamed: 99: 0 valores no nulos
# Unnamed: 100: 0 valores no nulos

# %%
#Si devuelve 0 → columna completamente vacía → podés eliminarla.

#Si hay algún número >0 → puede haber algún valor residual, quizás un espacio, o un artefacto del CSV.

# %%
df_sp500.drop(columns=unnamed_cols, inplace=True)

# %%
df_sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3049555 entries, 0 to 3049554
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Date           datetime64[ns]
#  1   Url            object
#  2   Article        object
#  3   Stock_symbol   object
#  4   Article_title  object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 116.3+ MB

# %%
# Convertir la columna Date a tipo datetime
df_sp500['Date'] = pd.to_datetime(df_sp500['Date'], errors='coerce')

# Agrupar por fecha y contar artículos
articulos_por_dia = df_sp500.groupby('Date').size()

# Graficar
plt.figure(figsize=(12, 5))
plt.plot(articulos_por_dia.index, articulos_por_dia.values)
plt.title('Cantidad de artículos por día')
plt.xlabel('Fecha')
plt.ylabel('Número de artículos')
plt.tight_layout()
plt.show()

# %%
# Convertir a datetime si no está hecho
df_sp500['Date'] = pd.to_datetime(df_sp500['Date'], errors='coerce')

# Filtrar años 2000-2020
df_sp500 = df_sp500[(df_sp500['Date'].dt.year >= 2000) & (df_sp500['Date'].dt.year <= 2020)]

# Agrupar por día y contar artículos
articulos_por_dia = df_sp500.groupby('Date').size()

# Crear un índice de fechas completo
fecha_inicio = df_sp500['Date'].min()
fecha_fin = df_sp500['Date'].max()
fechas_completas = pd.date_range(start=fecha_inicio, end=fecha_fin, freq='D')

# Reindexar para que los días sin artículos aparezcan con 0
articulos_por_dia = articulos_por_dia.reindex(fechas_completas, fill_value=0)

# %%
# df_sp500: tu sub-DataFrame filtrado y con Date tipo datetime
df_sp500['Date'] = pd.to_datetime(df_sp500['Date'], errors='coerce')

# Filtrar años 2000-2020
df_sp500 = df_sp500[(df_sp500['Date'].dt.year >= 2000) & (df_sp500['Date'].dt.year <= 2020)]

# Contar artículos por día
articulos_por_dia = df_sp500.groupby('Date').size()

# Crear índice de fechas completo
fecha_inicio = df_sp500['Date'].min()
fecha_fin = df_sp500['Date'].max()
fechas_completas = pd.date_range(start=fecha_inicio, end=fecha_fin, freq='D')

# Reindexar para que los días sin artículos aparezcan con 0
articulos_por_dia = articulos_por_dia.reindex(fechas_completas, fill_value=0)

# Pasar a DataFrame
df_dias = articulos_por_dia.reset_index()
df_dias.columns = ['Date', 'count']

# Crear columna Año-Mes como string
df_dias['YearMonth'] = df_dias['Date'].dt.strftime('%Y-%m')

# Contar días sin artículos por mes, incluyendo meses sin huecos
dias_sin_articulos = df_dias.groupby('YearMonth').apply(lambda x: (x['count'] == 0).sum())

# Mostrar resultados
print(dias_sin_articulos)
# Out:
# YearMonth
# 2009-04    18
# 2009-05    28
# 2009-06    21
# 2009-07    15
# 2009-08    19
#            ..
# 2020-08     0
# 2020-09     0
# 2020-10     0
# 2020-11     0
# 2020-12     0
# Length: 141, dtype: int64
# C:\Users\Ceci\AppData\Local\Temp\ipykernel_5388\1600041998.py:26: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   dias_sin_articulos = df_dias.groupby('YearMonth').apply(lambda x: (x['count'] == 0).sum())

# %%
dias_sin_articulos.to_csv('outputs/sp500_dias_sin_articulos.csv', header=['Dias_sin_articulos'])

# %%
#según esto, desde ene-2015 hasta dic-2020 hay al menos un artículo en la gran mayoría de los días (hay unos pocos meses con un día sin artículos).

# %%
# df_clean: tu sub-DataFrame filtrado con las 3 columnas no nulas
df_sp500['Date'] = pd.to_datetime(df_sp500['Date'], errors='coerce')
df_sp500 = df_sp500[(df_sp500['Date'].dt.year >= 2015) & (df_sp500['Date'].dt.year <= 2020)]

# Contar artículos por día
articulos_por_dia = df_sp500.groupby('Date').size()

# Crear DataFrame con año
df_dias = articulos_por_dia.reset_index()
df_dias.columns = ['Date', 'count']
df_dias['Year'] = df_dias['Date'].dt.year

# Configuración de subplots: 10 filas x 3 columnas
fig, axes = plt.subplots(nrows=6, ncols=1, figsize=(20, 50), sharex=False, sharey=False)
axes = axes.flatten()

years = range(2015, 2021)
for i, year in enumerate(years):
    ax = axes[i]
    data_year = df_dias[df_dias['Year'] == year]['count']
    
    # Histograma
    ax.hist(data_year, bins=30, color='skyblue', edgecolor='black')
    
    # Contar total de artículos en ese año
    total_articulos = data_year.sum()
    
    # Título con año + total de artículos
    ax.set_title(f'Año {year} (Artículos: {total_articulos})')
    ax.set_xlabel('Artículos por día')
    ax.set_ylabel('Días')
    
# Ocultar subplots sobrantes
for j in range(len(years), len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()

# %%
df_sp500.columns
# Out:
# Index(['Date', 'Url', 'Article', 'Stock_symbol', 'Article_title'], dtype='object')

# %%
df_sp500.Date.min(), df_sp500.Date.max()
# Out:
# (Timestamp('2015-01-01 00:00:00'), Timestamp('2020-12-31 00:00:00'))

# %%
# Contar artículos por User
articulos_por_stock_symbol = df_sp500['Stock_symbol'].value_counts()

top_stock_symbols = articulos_por_stock_symbol.head(30)

# Graficar horizontal
plt.figure(figsize=(10, 8))
top_stock_symbols.plot(kind='barh', color='skyblue', edgecolor='black')
plt.title('Cantidad de artículos por Stock_symbol top 30')
plt.xlabel('Número de artículos')
plt.ylabel('Stock_symbol')
plt.gca().invert_yaxis()  # Para que el top 1 quede arriba
plt.tight_layout()
plt.show()

# %%
print(df_sp500.Article.iloc[0])
# Out:
# Legendary investor Warren Buffett advises to be fearful when others are greedy, and be greedy when others are fearful. One way we can try to measure the level of fear in a given stock is through a technical analysis indicator called the Relative Strength Index, or RSI, which measures momentum on a scale of zero to 100. A stock is considered to be oversold if the RSI reading falls below 30.
# In trading on Wednesday, shares of Agilent Technologies, Inc. (Symbol: A) entered into oversold territory, hitting an RSI reading of 29.7, after changing hands as low as $74.46 per share. By comparison, the current RSI reading of the S&P 500 ETF (SPY) is 66.8. A bullish investor could look at A's 29.7 RSI reading today as a sign that the recent heavy selling is in the process of exhausting itself, and begin to look for entry point opportunities on the buy side. The chart below shows the one year performance of A shares:
# Looking at the chart above, A's low point in its 52 week range is $60.42 per share, with $82.27 as the 52 week high point — that compares with a last trade of $75.43.
# Find out what 9 other oversold stocks you need to know about »
# The views and opinions expressed herein are the views and opinions of the author and do not necessarily reflect those of Nasdaq, Inc.

# %% [markdown]
# Legendary investor Warren Buffett advises to be fearful when others are greedy, and be greedy when others are fearful. One way we can try to measure the level of fear in a given stock is through a technical analysis indicator called the Relative Strength Index, or RSI, which measures momentum on a scale of zero to 100. A stock is considered to be oversold if the RSI reading falls below 30.
# In trading on Wednesday, shares of Agilent Technologies, Inc. (Symbol: A) entered into oversold territory, hitting an RSI reading of 29.7, after changing hands as low as $74.46 per share. By comparison, the current RSI reading of the S&P 500 ETF (SPY) is 66.8. A bullish investor could look at A's 29.7 RSI reading today as a sign that the recent heavy selling is in the process of exhausting itself, and begin to look for entry point opportunities on the buy side. The chart below shows the one year performance of A shares:
# Looking at the chart above, A's low point in its 52 week range is $60.42 per share, with $82.27 as the 52 week high point — that compares with a last trade of $75.43.
# Find out what 9 other oversold stocks you need to know about »
# The views and opinions expressed herein are the views and opinions of the author and do not necessarily reflect those of Nasdaq, Inc.
